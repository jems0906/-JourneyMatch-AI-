# %% [markdown]
# # Explainability
# Inspect match dimensions and user-facing explanations.

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent / "backend"))
from app.recommender import recommend  # pyright: ignore[reportMissingImports]

result = recommend({'budget': 1800, 'climate': 'warm', 'interests': ['food'], 'accessibility': False})[0]
result['explanation'], result['breakdown']
