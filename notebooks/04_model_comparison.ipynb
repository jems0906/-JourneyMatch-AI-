# %% [markdown]
# # Model Comparison
# Measure coverage and deterministic ranking behavior on synthetic users.

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent))
from training.evaluate import evaluate

evaluate()
