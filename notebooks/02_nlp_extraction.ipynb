# %% [markdown]
# # NLP Preference Extraction
# Explore the deterministic keyword baseline before adding embeddings.

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent / "backend"))
from app.nlp import extract_preferences  # pyright: ignore[reportMissingImports]

extract_preferences('warm beach trip for food and culture around $2000 from ATL')
