# %% [markdown]
# # Destination EDA
# Inspect catalog size, climates, costs, and interests.

# %%
import csv
from pathlib import Path
rows = list(csv.DictReader((Path('data_samples') / 'destinations.csv').open()))
len(rows), rows[0]
