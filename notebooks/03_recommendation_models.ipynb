# %% [markdown]
# # Recommendation Models
# Compare the content and weighted scoring baseline.

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent / "backend"))
from app.recommender import recommend  # pyright: ignore[reportMissingImports]

recommend({'budget': 2000, 'climate': 'warm', 'interests': ['food', 'beach'], 'accessibility': True})
